# %%
import csv
import os
import time

from sentence_transformers import SentenceTransformer, util
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
url = "http://qim.fs.quoracdn.net/quora_duplicate_questions.tsv"
dataset_path = "quora_duplicate_questions.tsv"
max_corpus_size = 50000  # We limit our corpus to only the first 50k questions
util.http_get(url, dataset_path)
# Out:
#   0%|          | 0.00/58.2M [00:00<?, ?B/s]

# %%
# Get all unique sentences from the file
corpus_sentences = set()
with open(dataset_path, encoding="utf8") as fIn:
    reader = csv.DictReader(fIn, delimiter="\t", quoting=csv.QUOTE_MINIMAL)
    for row in reader:
        corpus_sentences.add(row["question1"])
        corpus_sentences.add(row["question2"])
        if len(corpus_sentences) >= max_corpus_size:
            break

# %%
# Model for computing sentence embeddings. We use one trained for similar questions detection
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
corpus_sentences = list(corpus_sentences)
print("Encode the corpus. This might take a while")
corpus_embeddings = model.encode(corpus_sentences, batch_size=85, show_progress_bar=True, convert_to_tensor=True)
# Out:
# Encode the corpus. This might take a while
# Batches:   0%|          | 0/589 [00:00<?, ?it/s]

# %%
start_time = time.time()
# Two parameters to tune:
# min_cluster_size: Only consider cluster that have at least 25 elements
# threshold: Consider sentence pairs with a cosine-similarity larger than threshold as similar
clusters = util.community_detection(corpus_embeddings, min_community_size=25, threshold=0.75)
print(f"Clustering done after {time.time() - start_time:.2f} sec")
# Out:
# Clustering done after 1.03 sec

# %%
# Print for all clusters the top 3 and bottom 3 elements
for i, cluster in enumerate(clusters):
    print(f"\nCluster {i + 1}, #{len(cluster)} Elements ")
    for sentence_id in cluster[0:3]:
        print("\t", corpus_sentences[sentence_id])
    print("\t", "...")
    for sentence_id in cluster[-3:]:
        print("\t", corpus_sentences[sentence_id])
# Out:
# Cluster 1, #103 Elements
# 	 How can I improve my spoken English?
# 	 How will I improve my spoken English?
# 	 What should I do to improve my spoken English?
# 	 ...
# 	 How can I increase my knowledge in English language?
# 	 How do I improve my English writing and speaking skills?
# 	 What should I do to speak English fluently and not face any problem with vocabulary?
#
# Cluster 2, #86 Elements
# 	 How can one make money online?
# 	 How could I make money online?
# 	 How do I to make money online?
# 	 ...
# 	 How can an apprentice programmer make money online?
# 	 How do I earned big money even online without investment?
# 	 What are the ways to make money working from home?
#
# Cluster 3, #82 Elements
# 	 What are the economic implications of banning 500 and 1000 rupee notes?
# 	 What will be the implications of banning 500 and 1000 rupees currency notes on Indian economy?
# 	 How will the ban of 1000 and 500 rupee notes affect the Indian economy?
# 	 ...
# 	 What are your views over discontinuation of Rs 500 and Rs 1000 notes? What will be it’s outcome ?
# 	 What will government do with 1000 rs & 500 rs notes?
# 	 How much black money will be controlled by banning Rs 500 and Rs 1000 note?
#
# Cluster 4, #81 Elements
# 	 What are some things new employees should know going into their first day at Conn's?
# 	 What are some things new employees should know going into their first day at Epizyme?
# 	 What are some things new employees should know going into their first day at Guaranty?
# 	 ...
# 	 What are some things new employees should know going into their first day at Pennsylvania REIT?
# 	 What are some things new employees should know going into their first day at Omega Protein?
# 	 What are some things new employees should know going into their first day at Quantum?
#
# Cluster 5, #67 Elements
# 	 What is a suitable inpatient drug and alcohol rehab center near Morgan County IL?
# 	 What is a suitable inpatient drug and alcohol rehab center near Cook County IL?
# 	 What is a suitable inpatient drug and alcohol rehab center near Bond County IL?
# 	 ...
# 	 Is there a Drug and Alcohol Rehab Center in Juneau County AK?
# 	 Is there a Drug and Alcohol Rehab Center in Anchorage County AK?
# 	 Is there a Drug and Alcohol Rehab Center in Petersburg County AK?
#
# Cluster 6, #64 Elements
# 	 What is the best programming language I should start learning?
# 	 What is the best programming language I should learn as a beginner?
# 	 Which is the best programming language for a beginner to learn?
# 	 ...
# 	 Before I start to learn programming what should I learn first?
# 	 What is the best language to learn after C and C++?
# 	 What is the easy way to learn a programming language?
#
# Cluster 7, #54 Elements
# 	 What are the best ways to lose weight?
# 	 What are some good ways to lose weight?
# 	 What is the best method of losing weight?
# 	 ...
# 	 How do I lose weight without quitting?
# 	 What are the best ways to lose a lot of weight as quickly as possible?
# 	 How can I lose weight slowly and naturally?
#
# Cluster 8, #51 Elements
# 	 Why do people bother to ask questions on Quora they could just google to get the answer?
# 	 Why do people often ask questions in Quora while they can Google it themselves?
# 	 Why do people ask questions on Quora that can easily be answered by Google?
# 	 ...
# 	 Why do so many people ask questions on Quora instead of searching the answers on Wikipedia?
# 	 Is it bad to ask questions on Quora that could easily be answered via a Google search?
# 	 Why should we use Quora when we can Google everything?
#
# Cluster 9, #51 Elements
# 	 I do not remember my password to my Gmail account, how can I recover my account?
# 	 How do I recover my Gmail account if I forgot my Gmail password?
# 	 How can I recover my Gmail account's password?
# 	 ...
# 	 How do I reset my email password?
# 	 I have a Gmail address and can't remember the password. The only pictures of my son I own are on it. How do I go about getting into my account?
# 	 How do I reset a Gmail password without a phone number?
#
# Cluster 10, #50 Elements
# 	 How can I reduce my Belly and tummy fat?
# 	 How can I reduce tummy fat?
# 	 How can I reduce my weight and tummy?
# 	 ...
# 	 What daily quick exercise can help reduce belly & thigh's Fat?
# 	 What is the best exercise for belly fat?
# 	 How do I get rid of visible fat on my chest and belly?
#
# Cluster 11, #48 Elements
# 	 What is the meaning or purpose of life?
# 	 What is the meaning and purpose to life?
# 	 What is the purpose of life?
# 	 ...
# 	 What the meaning of this all life?
# 	 How do we know the purpose of our life?
# 	 What is the definition of life?
#
# Cluster 12, #42 Elements
# 	 How can anyone increase height?
# 	 How can you increase your height?
# 	 How could I increase my height?
# 	 ...
# 	 How can I grow tall?
# 	 Can height be increased after age 21?
# 	 Does height increase after 21? How can I get taller?
#
# Cluster 13, #41 Elements
# 	 Which is a good solar panel installation provider in Long Beach, California CA?
# 	 Which is a good solar panel installation provider in Pacific Beach, California CA?
# 	 Which is a good solar panel installation provider near Stinson Beach, California CA?
# 	 ...
# 	 What is a suitable solar panel installation provider near Prescott, Arizona AZ?
# 	 What is a suitable solar panel installation provider in Yuma, Arizona AZ?
# 	 What is a suitable solar panel installation provider near Peoria, Arizona AZ?
#
# Cluster 14, #40 Elements
# 	 What is the most painless way to commit suicide?
# 	 What is the most painless way to do a suicide?
# 	 What is the easiest and painless way to commit suicide?
# 	 ...
# 	 What is the best way to commit suicide in India?
# 	 What is the least painful way to die?
# 	 What's the least painful way to die?
#
# Cluster 15, #39 Elements
# 	 Is world war 3 likely?
# 	 Is World War 3 coming?
# 	 Is world War 3 currently happening?
# 	 ...
# 	 How close are we to World War Three, and how bad would it be?
# 	 What are the chances of ww3?
# 	 Why World War III are inevitable?
#
# Cluster 16, #39 Elements
# 	 Will Pakistan have a war with India?
# 	 Will India fight a war with Pakistan?
# 	 Will India fight a war against Pakistan?
# 	 ...
# 	 Will there really be any war between India and Pakistan over the Uri attack? What will be its effects?
# 	 Will Russia support India, in case of war with Pakistan?
# 	 What will happen if India and Pakistan are a friendly nation?
#
# Cluster 17, #39 Elements
# 	 Why does Quora keep marking my questions as "needing improvement"?
# 	 Why does Quora always mark my questions as needing improvement?
# 	 Why does quora mark my questions as needing improvement?
# 	 ...
# 	 Why are my questions always flagged as needing improvement?
# 	 Why are these questions marked as needing improvement?
# 	 Why do questions I answer almost immediately get marked as needing improvement? Is it something I said?
#
# Cluster 18, #39 Elements
# 	 Which is the best phone to buy within Rs.15000?
# 	 Which is the best phone to buy under Rs.1500?
# 	 Which is the best phone under 15000 Rs.?
# 	 ...
# 	 What is the best smartphone available in India under 15k?
# 	 Which is the best phone to buy under Rs. 7000?
# 	 Which is the best camera phone for 13000?
#
# Cluster 19, #39 Elements
# 	 What hotel in Surat would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?
# 	 What hotel in Fatehpur would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?
# 	 What hotel in Bhopal would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?
# 	 ...
# 	 What hotel in Araku Valley Hill-station would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?
# 	 What hotel in Gangtok Hill-station would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?
# 	 What hotel in Nepal would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?
#
# Cluster 20, #38 Elements
# 	 How banning 500 and 1000 rs note will help fight corruption in India?
# 	 How will scraping of 500 and 1000 rupees notes help in curbing corruption and black money?
# 	 Will banning Rs.500 and Rs.1000 notes help to solve black money and corruption?
# 	 ...
# 	 How does invalidating the current Rs. 500 and Rs. 1000 currency notes help in weeding out black money?
# 	 Why is the Indian government not abolishing the currency note of 500 and 1000 to reduce black money?
# 	 What will happen to corruption money deposited by Indian politicians in Swiss bank after banning 500 and 1000 rupees notes?
#
# Cluster 21, #37 Elements
# 	 What are some meaningful new year resolutions for 2017?
# 	 What are some new year resolutions for 2017?
# 	 What are your New Years resolutions for 2017?
# 	 ...
# 	 What's your resolution for year 2016?
# 	 What are PhD students' 2016 new year resolutions?
# 	 What's your new year resolution do or not to do?
#
# Cluster 22, #37 Elements
# 	 How do I control my emotions and anger?
# 	 How can I control on my anger?
# 	 How can I control my anger?
# 	 ...
# 	 How do I gain emotional intelligence and control my emotions?
# 	 How do I calm myself down in anger?
# 	 What are some effective ways to curb your anger?
#
# Cluster 23, #37 Elements
# 	 How can I gain weight?
# 	 How do I gain weight?
# 	 How to gain weight ?
# 	 ...
# 	 How do I gain weight fast, without expensive supplements?
# 	 Which is the best food to gain weight?
# 	 How do I gain healthy weight without eating junk?
#
# Cluster 24, #36 Elements
# 	 Is time travel possible?
# 	 Time Travel Is It Possible?
# 	 Is time travel possible? If yes? How?
# 	 ...
# 	 How can I do time travel?
# 	 What do you hAve to say about time travel (I am not science student but I read it on net and its so exciting topic but still no clear idea that is it possible or it's just a rumour)?
# 	 Is time traval possible in future?
#
# Cluster 25, #35 Elements
# 	 How can I increase the traffic to my website?
# 	 How can I increase the traffic on my website?
# 	 How to increase my website Traffic?
# 	 ...
# 	 How can I increase my website organic search traffic?
# 	 How can I increase the traffic on my blog (www.midnightexpressions.wordpress.com)?
# 	 What is the best way to increase traffic for a new blog?
#
# Cluster 26, #34 Elements
# 	 What is the Sahara, and how do the average temperatures there compare to the ones in the Gobi Desert?
# 	 What is the Sahara, and how do the average temperatures there compare to the ones in the Arabian Desert?
# 	 What is the Sahara, and how do the average temperatures there compare to the ones in the Thar Desert?
# 	 ...
# 	 How cold can the Gobi Desert get, and how do its average temperatures compare to the ones in the Dasht-e Margo?
# 	 How cold can the Gobi Desert get, and how do its average temperatures compare to the ones in the Colorado Plateau?
# 	 How cold can the Gobi Desert get, and how do its average temperatures compare to the ones in the Chihuahuan Desert?
#
# Cluster 27, #33 Elements
# 	 How can I hack whatsapp?
# 	 How do I hack WhatsApp?
# 	 What is the way to hack WhatsApp?
# 	 ...
# 	 Can you hack my crush's WhatsApp account for me?
# 	 How do you spy on WhatsApp messages?
# 	 How can I use WhatsApp in a computer?
#
# Cluster 28, #33 Elements
# 	 How should I start preparing for UPSC(IAS) exams?
# 	 How do I start preparing for UPSC exam?
# 	 How do I start preparation for upsc exams?
# 	 ...
# 	 How can I start preparations for the UPSC Civil Services Examinations 2018-19?
# 	 How do I prepare for GPSC/UPSC exams?
# 	 How do I prepare for upsc prelim?
#
# Cluster 29, #32 Elements
# 	 What are the strongest majors in terms of job prospects and what are the weakest majors at Hunter College?
# 	 What are the strongest majors in terms of job prospects and what are the weakest majors at Cal State Northridge?
# 	 What are the strongest majors in terms of job prospects and what are the weakest majors at Wilson College?
# 	 ...
# 	 What are the strongest majors in terms of job prospects and what are the weakest majors at Ball State?
# 	 What are the strongest majors in terms of job prospects and what are the weakest majors at NYU?
# 	 What are the strongest majors in terms of job prospects and what are the weakest majors at Texas A&M?
#
# Cluster 30, #32 Elements
# 	 What is the best way to get rid of acne?
# 	 How do I get rid of acne naturally?
# 	 How can I get rid of my acne?
# 	 ...
# 	 Is there a cure for acne? Why or why not?
# 	 How do you treat acne scars?
# 	 What are the best cures for pimples and oily skin?
#
# Cluster 31, #31 Elements
# 	 What is most embarrassing moment of your life?
# 	 What are the embarrassing moment of your life?
# 	 What is the best embarrassing moment of your life?
# 	 ...
# 	 What is the most awkward moment you have ever experienced?
# 	 What's the most embarrassing thing that happened to you on a date?
# 	 What is the most embarrassing photo you have ever taken of others?
#
# Cluster 32, #31 Elements
# 	 How do I concentrate in a better way on studies?
# 	 How do I concentrate better in my studies?
# 	 How do I concentrate better in my study?
# 	 ...
# 	 How can I make my study more effective?
# 	 What are the best ways to study more effectively?
# 	 What are some tips to concentrate when reading or at work? I find my mind wanders and I know I am not being as productive as I should be.
#
# Cluster 33, #31 Elements
# 	 What are best novels to read?
# 	 Which are the best novels?
# 	 What are the best novels ever?
# 	 ...
# 	 What are your favorite books of all time? And why?
# 	 What is the best historical fiction romance book you have ever read?
# 	 What are the best historical fiction books you have ever read?
#
# Cluster 34, #30 Elements
# 	 How can I improve my English speaking skills as well as writing skills?
# 	 How can I improve my English writing skills?
# 	 How can I improve my English writing skills in an effective way?
# 	 ...
# 	 How can I hone my writing skills?
# 	 How do I improve my writing?
# 	 How do we enhance our writing skill?
#
# Cluster 35, #30 Elements
# 	 Why did Indian government scrap Rs 1000 and 500 note and instead is introducing Rs 2000 note?
# 	 Why did the government of India introduced a 2000 rupee note instead of a new 1000 rupee note?
# 	 Why did Indian government did not reissue 1000 rupee note but instead introduced a 2000 rupee note?
# 	 ...
# 	 Why Narendra Modi banned 500 and 1000 notes in India?
# 	 Why were the 500 and 1000 rupee notes demonetized?
# 	 Why did Modi ban 500 and 1000 rupees notes and not 100 rupee notes?
#
# Cluster 36, #30 Elements
# 	 Which is the best course for digital marketing?
# 	 Which is the best digital marketing course?
# 	 Which is best digital marketing course?
# 	 ...
# 	 How can I learn & start a digital marketing company?
# 	 Which is the best institute to learn digital marketing (job oriented) in India?
# 	 what is the way to start career in digital marketing?
#
# Cluster 37, #29 Elements
# 	 What are your views on the ban of Rs 500 and Rs 1000 notes by the Indian Government? Pros cons?
# 	 What do you think about the ban on 500 and 1000 denomination notes in India?
# 	 What do you think of abolishing 500 and 1000 Rupee Currency notes by the Indian Government?
# 	 ...
# 	 What do you think of the decision by the Indian Government to replace 1000 notes with 2000 notes?
# 	 What will be the pros and cons of the replacement of 500 and 1000 currency notes by the Indian govt.?
# 	 Don't you think Modi will repeal decision to ban 500 and 1000 notes as it will cause high inconvenience?
#
# Cluster 38, #29 Elements
# 	 What should i do to overcome depression ?
# 	 How should I overcome my depression?
# 	 How do I overcome from depression and stress?
# 	 ...
# 	 What should i do when i feel depressed?
# 	 What can I do if I feel depressed?
# 	 How can you come out of depression?
#
# Cluster 39, #29 Elements
# 	 How does the GST bill benefit the common man in India?
# 	 What's the importance of GST bill in India?
# 	 What are the benefits of GST bill for common peoples?
# 	 ...
# 	 What will be the impact of GST in India?
# 	 How is a common man benifited/affected by GST?
# 	 How can the GST bill, passed by the Rajyasabha yesterday, boost the Indian economy?
#
# Cluster 40, #28 Elements
# 	 What is the the best way to learn programming?
# 	 What are some of the best ways to learn programming?
# 	 How can I learn more programming?
# 	 ...
# 	 How do I start programming?
# 	 What is the simplest way to learn how to code?
# 	 Which are the best book to learn programming for beginners?
#
# Cluster 41, #28 Elements
# 	 What are the safety precautions on handling shotguns proposed by the NRA in Arkansas?
# 	 What are the safety precautions on handling shotguns proposed by the NRA in Mississippi?
# 	 What are the safety precautions on handling shotguns proposed by the NRA in Washington?
# 	 ...
# 	 What are the safety precautions on handling shotguns proposed by the NRA in Massachisetts?
# 	 What are the safety precautions on handling shotguns proposed by the NRA in Vermont?
# 	 What are the safety precautions on handling shotguns proposed by the NRA in Utah?
#
# Cluster 42, #28 Elements
# 	 What are the best horror movies of 2016?
# 	 What are some best horror movies of 2016?
# 	 Which were the best horror films of 2016?
# 	 ...
# 	 What are the top 10 horror movies of all time?
# 	 What are the top 10 movies of 2016 (any genre)?
# 	 What are your 10 favorite horror movies?
#
# Cluster 43, #28 Elements
# 	 What are best Hollywood movies?
# 	 What are the best movies of Hollywood?
# 	 What are some of the best Hollywood movies to watch?
# 	 ...
# 	 Which are the best Hollywood romantic movies?
# 	 Which are best Hollywood song?
# 	 What are the best movies you ever watch?
#
# Cluster 44, #27 Elements
# 	 What is the funniest joke you ever heard?
# 	 What is funniest joke you've ever heard?
# 	 Which is the funniest joke you've ever heard?
# 	 ...
# 	 What are some of the best jokes?
# 	 What is the funniest thing you ever said?
# 	 What are the all time best jokes?
#
# Cluster 45, #27 Elements
# 	 How can long distance relationships be successful?
# 	 How can I have a successful long distance relationship?
# 	 How will long distance relationship work?
# 	 ...
# 	 Do long distance relationships ever work out?
# 	 How do I cope with a long distance relationship?
# 	 Which are some successful long distance relationship stories?
#
# Cluster 46, #27 Elements
# 	 How do I stop my addiction to porn and masturbation?
# 	 How do I stop addiction to porn?
# 	 How can I stop my porn addiction?
# 	 ...
# 	 How can I stop watching porn?
# 	 How can one stop masturbation?
# 	 How do I quit masturbation?
#
# Cluster 47, #27 Elements
# 	 What are some mind blowing technology gadgets that most people don't know?
# 	 What are some mind-blowing gadgets and technologies that exist that most people don't know about?
# 	 What are some mind-blowing futuristic gadgets that exist that most people don't know about?
# 	 ...
# 	 What are some mind-blowing computer tools that exist that most people don't know about?
# 	 What are some mind blowing phone tools that most people don't know about?
# 	 What are some mind blowing Car gadgets?
#
# Cluster 48, #26 Elements
# 	 Who will win the 2016 presidential election?
# 	 Who will win the 2016 presidential elections?
# 	 Who is going to win the 2016 presidential election?
# 	 ...
# 	 Who do you think will win Trump or Clinton?
# 	 Who will be the next president of USA 2016?
# 	 Who will win, Trump or Clinton?
#
# Cluster 49, #26 Elements
# 	 We are Planning to visit Goa for three days,which are the best places to visit?
# 	 What are all the best places to visit in goa?
# 	 Which are best places to visit in GOA during vacations?
# 	 ...
# 	 Out of all the beaches in Goa, which one is the best beach to go to?
# 	 What are some nice budget places to stay in Goa?
# 	 What is a plan for a 2 days/1 night trip to Goa?
#
# Cluster 50, #26 Elements
# 	 How and Why did Donald Trump win the election?
# 	 How did Donald Trump win the election?
# 	 Why did Donald Trump win the election?
# 	 ...
# 	 How is Donald Trump winning?
# 	 How did Donald Trump become president?
# 	 Why did America vote for Donald Trump as President in the 2016 Elections?
#
# Cluster 51, #26 Elements
# 	 How is your first sex experience?
# 	 What was your first sex experience?
# 	 How is first time sex experience?
# 	 ...
# 	 How was your first masturbation experience? When was it?
# 	 What is the best sex experience you've ever had? (gay or straight)
# 	 How does it feel to have sex?
#
# Cluster 52, #26 Elements
# 	 What is your biggest mistake or regret?
# 	 What is the biggest mistake you have ever made in your life and regret it alot?
# 	 What is your biggest regret of your life?
# 	 ...
# 	 What mistake have you learned the most from?
# 	 What is the biggest mistake you made in your 30s and what did you learn from it?
# 	 What is the most common mistake people make?
#
# Cluster 53, #25 Elements
# 	 Why is saltwater Taffy candy imported in Canada?
# 	 Why is Saltwater taffy candy imported in Australia?
# 	 Why is Saltwater taffy candy imported in China?
# 	 ...
# 	 Why is Saltwater taffy candy imported in Laos?
# 	 Why are saltwater taffy imported in Japan?
# 	 Why is salt water taffy candy unknown in Japan?
#
# Cluster 54, #25 Elements
# 	 Can you see who viewed your Instagram?
# 	 Can you see who views your Instagram?
# 	 Can you see who view your Instagram?
# 	 ...
# 	 How can you tell who has viewed Instagram videos?
# 	 Can you see who liked a photo from Instagram on the computer?
# 	 Can you really see who viewed your profile on Facebook?
#
# Cluster 55, #25 Elements
# 	 What affects India if Donald Trump becomes president?
# 	 If Donald Trump becomes the president of USA, how will it affect India?
# 	 If Trump becomes President, how will it affect India?
# 	 ...
# 	 What would be the scenario for Indian students after Donald trump becomes the President of US?
# 	 How will Donald Trump becoming a president affect the Indian students who are trying to pursue their masters in America?
# 	 What should Indians do if Donald Trump becomes President?
#
# Cluster 56, #25 Elements
# 	 I forgot my Instagram password. How can I get into my account?
# 	 How do I get into my Instagram if I forgot my email and my Facebook password?
# 	 How can I reset password of Instagram account without email?
# 	 ...
# 	 How do I delete old Instagram account without the password or email?
# 	 How do you get your Instagram back, once you've been hacked?
# 	 How do I delete an Instagram account if I don't know the email or password?
#
# Cluster 57, #25 Elements
# 	 What are some best MBA colleges are there in India?
# 	 Which are the best reputed MBA colleges in India?
# 	 What are the Top mba colleges in india with better placemens?
# 	 ...
# 	 Are there any colleges in North India that offer an MBA in hospitality & tourism and good placements as well?
# 	 Which are the top 50 business schools in India?
# 	 Which are the top 10 colleges in India for commerce?
#
# Cluster 58, #25 Elements
# 	 If I want to invest in the stock market, how I start?
# 	 How can I get started in stock market?
# 	 How do I invest in stock market?
# 	 ...
# 	 How do I make a profit in the stock market?
# 	 I'm 18 and want to learn the stock market how could I teach myself the basics?
# 	 What is the best way to learn about investing in the stock market and what stocks to buy?
#
# Cluster 59, #25 Elements
# 	 How can I add a photo to my Quora?
# 	 How do I add photos on Quora?
# 	 How can I add pictures on Quora?
# 	 ...
# 	 How do I change my profile photo in here on Quora?
# 	 How do I upload pictures to Quora questions?
# 	 How can pictures be uploaded in Quora?
#
# Cluster 60, #25 Elements
# 	 Is dark/vacuum energy infinite because the expansion of the universe is infinite and more and more of it is created as the universe expands?
# 	 If dark/vacuum energy is created with expansion and it has no limit, can infinite energy be created then?
# 	 If dark/vacuum energy is created with expansion and it has no limit, could infinite energy be created then?
# 	 ...
# 	 Why does dark energy expand universe?
# 	 Is the potential energy of vacuum energy, virtual particles and/or dark energy infinite? NO MERGE
# 	 If energy is not conserved in an expanding universe, is potential energy infinite (the energy that can be created is infinite)?
#
# Cluster 61, #25 Elements
# 	 What are the best places to visit in Kerala?
# 	 What are the best places to visit in Kerala for 3 to 4 days?
# 	 What are some good places to visit in Kerala on tour?
# 	 ...
# 	 Which are the prospering towns in Kerala?
# 	 What is the best places in India to travel?
# 	 What can be the medium budget to visit best places in Kerala for three members (2-3 days)?
